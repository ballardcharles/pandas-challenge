# %%
# Import dependencies
import pandas as pd
import numpy as np

# Create file path to load CSV
file_path = "Resources/purchase_data.csv"

# Read file to store in Pandas data frame

purchase_data = pd.read_csv(file_path)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Create count of players
players_total = len(purchase_data["SN"].unique())
# Create data frame to display count of players
total_players_df = pd.DataFrame({"Total Players": players_total}, index=[0])
total_players_df
# Out:
#    Total Players
# 0            576

# %%
# Create Data Frame with Purchasing Analysis
# Calculate number of unique items for sale
num_unique_items = len(purchase_data["Item ID"].unique())

# Calculate the average purchase price
avg_purchase_price = purchase_data["Price"].mean()

# Calculate the total number of purchases
num_of_purchases = len(purchase_data)

# Calculate the total Revenue
total_revenue = purchase_data["Price"].sum()

# Create data frame to hold Purchase Analysis
purchase_analysis_df = pd.DataFrame({
    "Number of Unique Items" : num_unique_items,
    "Average Price" : "${:,.2f}".format(avg_purchase_price),
    "Number of Purchases" : num_of_purchases,
    "Total Revenue" : "${:,.2f}".format(total_revenue)
}, index=[0])

purchase_analysis_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
# Create Gender Demographics Summary

# Create Gender Group
gender_group = purchase_data.groupby('Gender')

# Create count of unique users in each gender group
gender_count = gender_group['SN'].nunique()

# Create percents of each gender group of the total list of players
gender_percents = (gender_count/players_total) * 100

# Create dataframe to hold the gender summary
gender_summary = pd.DataFrame({
    "Total Count": gender_count,
    "Percentage of Players": gender_percents,
})

# Apply formatting to gender summary dataframe
gender_summary.style.format({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_80cac39a_55cd_11eb_ae55_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80cac39a_55cd_11eb_ae55_acde48001122level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_80cac39a_55cd_11eb_ae55_acde48001122row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_80cac39a_55cd_11eb_ae55_acde48001122row0_col1" class="data row0 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_80cac39a_55cd_11eb_ae55_acde48001122level0_row1" class="row_heading level0 row1" >Male</th>
# ...

# %%
# Create Purchase Analysis by Gender

# Calculate the total purchase count by gender group
gen_group_pur_count = gender_group['Purchase ID'].count()

# Calculate the average purchase price per gender group
gen_group_avg = gender_group['Price'].mean()

# Calculate the total purchase amount by gender group
gen_group_total = gender_group['Price'].sum()

# Calculate the average purchase price per person
avg_per_person = gen_group_total / gender_count

# Create dataframe to house Purchase Analysis by Gender
gender_purchase_df = pd.DataFrame({
    "Purchase Count" : gen_group_pur_count,
    "Average Purchase Price" : gen_group_avg,
    "Total Purchase Value" : gen_group_total,
    "Avg Total Purchase per Person" : avg_per_person
})

# Format Dataframe
gender_purchase_df.style.format({"Average Purchase Price":"${:,.2f}",
                                  "Total Purchase Value":"${:,.2f}",
                                  "Avg Total Purchase per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_8143b3fe_55cd_11eb_8df9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8143b3fe_55cd_11eb_8df9_acde48001122level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_8143b3fe_55cd_11eb_8df9_acde48001122row0_col0" class="data row0 col0" >113</td>
# ...

# %%
# Create Age Demographics Summary
bins = [0,9,14,19,24,29,34,39,100]

labels = ['<10','10-14','15-19','20-24','25-29','30-34','35-39','40+']

purchase_data['Age Group'] = pd.cut(purchase_data['Age'], bins, labels=labels)

age_group = purchase_data.groupby('Age Group')

age_count = age_group['SN'].nunique()

age_percent = (age_count/players_total)*100

age_demo_summary = pd.DataFrame({
    'Total Count':age_count,
    'Percentage of Players':age_percent
})

age_demo_summary.style.format({'Percentage of Players':"{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_827e6f48_55cd_11eb_a18f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_827e6f48_55cd_11eb_a18f_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_827e6f48_55cd_11eb_a18f_acde48001122row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_827e6f48_55cd_11eb_a18f_acde48001122row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_827e6f48_55cd_11eb_a18f_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
# ...

# %%
# Create purchase analysis by age group

# Calculate the total purchase count by age group
age_group_pur_count = age_group['Purchase ID'].count()

# Calculate the average purchase price per age group
age_group_avg = age_group['Price'].mean()

# Calculate the total purchase amount by age group
age_group_total = age_group['Price'].sum()

# Calculate the average purchase price per person by age group
age_avg_per_person = age_group_total / age_count

# Create dataframe to house Purchase Analysis by age group
age_purchase_df = pd.DataFrame({
    "Purchase Count" : age_group_pur_count,
    "Average Purchase Price" : age_group_avg,
    "Total Purchase Value" : age_group_total,
    "Avg Total Purchase per Person" : age_avg_per_person
})

# Format Dataframe
age_purchase_df.style.format({"Average Purchase Price":"${:,.2f}",
                                  "Total Purchase Value":"${:,.2f}",
                                  "Avg Total Purchase per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_830f0ef4_55cd_11eb_b7c1_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_830f0ef4_55cd_11eb_b7c1_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_830f0ef4_55cd_11eb_b7c1_acde48001122row0_col0" class="data row0 col0" >23</td>
# ...

# %%
# Create Top Spenders Analysis

# Create group for screen names
sn_group = purchase_data.groupby('SN')

# Calculate the number of purchases by screen name
sn_counts = sn_group['SN'].count()

# Calculate the average price per purchase by screen name
sn_avg_price = sn_group['Price'].sum()/sn_counts

# Calculate the purchase total by screen name
sn_total_purchase = sn_group['Price'].sum()

# Put screen name purchase summary into dataframe
sn_purchase_sum = pd.DataFrame({
    'Purchase Count':sn_counts,
    'Average Purchase Price':sn_avg_price,
    'Total Purchase Value':sn_total_purchase
})

# Sort by number of purchases
sn_purchase_sum_sorted = sn_purchase_sum.sort_values('Purchase Count', ascending=False).head()

# Format and print dataframe
sn_purchase_sum_sorted.style.format({
    'Average Purchase Price':"${:,.2f}",
    'Total Purchase Value':"${:,.2f}"
})
# Out:
# <style  type="text/css" >
# </style><table id="T_0a7c60e8_55cf_11eb_8797_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a7c60e8_55cf_11eb_8797_acde48001122level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_0a7c60e8_55cf_11eb_8797_acde48001122row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_0a7c60e8_55cf_11eb_8797_acde48001122row0_col1" class="data row0 col1" >$3.79</td>
# ...
